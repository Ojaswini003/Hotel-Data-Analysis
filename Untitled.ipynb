# %%
import pandas as pd

# %%
df_bookings=pd.read_csv("datasets/fact_bookings.csv")
df_bookings.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100
# 3               9100              3640

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot()
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.booking_platform.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.booking_platform.value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
df_date=pd.read_csv('datasets/dim_date.csv')
df_hotels=pd.read_csv('datasets/dim_hotels.csv')
df_rooms=pd.read_csv('datasets/dim_rooms.csv')
df_agg_bookings=pd.read_csv('datasets/fact_aggregated_bookings.csv')

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head(4)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='city'>

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0

# %%
df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %%
df_agg_bookings.groupby("property_id")["successful_bookings"].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings.capacity.max()
# Out:
# np.float64(50.0)

# %% [raw]
# DATA CLEANING

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# 17924       14-05-22      -10.0           RT4    direct online            NaN
# 18020       14-05-22      -12.0           RT2     makeyourtrip            NaN
# 18119       17-05-22       -6.0           RT3   direct offline            5.0
# 18121       17-05-22       -4.0           RT3    direct online            NaN
# 56715       13-06-22      -17.0           RT1           others            NaN
# 119765      22-07-22       -1.0           RT2           others            NaN
# 134586      1/8/2022       -4.0           RT4          logtrip            2.0
#
#        booking_status  revenue_generated  revenue_realized
# 0         Checked Out              10010             10010
# 3           Cancelled               9100              3640
# 17924         No Show              20900             20900
# 18020       Cancelled               9000              3600
# 18119     Checked Out              16800             16800
# 18121       Cancelled              14400              5760
# 56715     Checked Out               6500              6500
# 119765    Checked Out              13500             13500
# 134586    Checked Out              38760             38760

# %%
df_bookings[df_bookings.no_guests>0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 4           2/5/2022        4.0           RT1    direct online            5.0
# 5           3/5/2022        2.0           RT1           others            4.0
# 6           6/5/2022        2.0           RT1           others            NaN
# ...              ...        ...           ...              ...            ...
# 134584      1/8/2022        2.0           RT4           others            2.0
# 134585      3/8/2022        1.0           RT4     makeyourtrip            2.0
# 134587      2/8/2022        1.0           RT4         tripster            NaN
# 134588      1/8/2022        2.0           RT4          logtrip            2.0
# 134589      1/8/2022        2.0           RT4     makeyourtrip            NaN
#
#        booking_status  revenue_generated  revenue_realized
# 1           Cancelled               9100              3640
# 2         Checked Out            9100000              9100
# 4         Checked Out              10920             10920
# 5         Checked Out               9100              9100
# 6           Cancelled               9100              3640
# ...               ...                ...               ...
# 134584    Checked Out              32300             32300
# 134585    Checked Out              32300             32300
# 134587      Cancelled              32300             12920
# 134588    Checked Out              32300             32300
# 134589      Cancelled              32300             12920
#
# [134578 rows x 12 columns]

# %%
df_bookings=df_bookings[df_bookings.no_guests>0]
df_bookings.shape
# Out:
# (134578, 12)

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (np.int64(6500), np.int64(28560000))

# %%
avg,std=df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()

# %%
avg,std
# Out:
# (np.float64(15378.036937686695), np.float64(93040.1549314641))

# %%
higher_limit=avg+3*std
higher_limit
# Out:
# np.float64(294498.50173207896)

# %%
lower_limit=avg-3*std
lower_limit
# Out:
# np.float64(-263742.4278567056)

# %%
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# 2         Checked Out            9100000              9100
# 111       Checked Out           28560000             28560
# 315       Checked Out           12600000             12600
# 562         Cancelled            2000000              4420
# 129176    Checked Out           10000000             12600

# %%
df_bookings=df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
higher_limit=df_bookings.revenue_realized.mean()+3*df_bookings.revenue_realized.std()
higher_limit
# Out:
# np.float64(33479.358661845814)

# %%
df_bookings[df_bookings.revenue_realized>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# 139         2/5/2022        6.0           RT4         tripster            3.0
# 143         3/5/2022        3.0           RT4           others            5.0
# 149         7/5/2022        5.0           RT4          logtrip            NaN
# 222         3/5/2022        5.0           RT4           others            3.0
# ...              ...        ...           ...              ...            ...
# 134328      2/8/2022        6.0           RT4    direct online            5.0
# 134331      1/8/2022        6.0           RT4           others            2.0
# 134467      1/8/2022        6.0           RT4     makeyourtrip            4.0
# 134474      6/8/2022        5.0           RT4   direct offline            5.0
# 134581      1/8/2022        4.0           RT4     makeyourtrip            4.0
#
#        booking_status  revenue_generated  revenue_realized
# 137       Checked Out              38760             38760
# 139       Checked Out              45220             45220
# 143       Checked Out              35530             35530
# 149       Checked Out              41990             41990
# 222       Checked Out              34580             34580
# ...               ...                ...               ...
# 134328    Checked Out              39900             39900
# 134331    Checked Out              39900             39900
# 134467    Checked Out              39900             39900
# 134474    Checked Out              37050             37050
# 134581    Checked Out              38760             38760
#
# [1299 rows x 12 columns]

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_bookings=pd.read_csv("datasets/fact_bookings.csv")

# %%
df_bookings[df_bookings.room_category=="RT4"].revenue_realized.describe()
# Out:
# count    16073.000000
# mean     23440.103652
# std       9048.865206
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
23440+3*9048
# Out:
# 50584

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                3
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_agg_bookings.capacity.median()
# Out:
# np.float64(25.0)

# %%
df_agg_bookings.fillna({'capacity': df_agg_bookings['capacity'].median()}, inplace=True)

# %%
df_agg_bookings.loc[[8,14]]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22      25.0
# 14        17562      1-May-22           RT1                   12      25.0

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings = df_agg_bookings[df_agg_bookings.successful_bookings<=df_agg_bookings.capacity]
df_agg_bookings.shape
# Out:
# (9194, 5)

# %% [markdown]
# **DATA TRANSFORMATION**

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0

# %%
df_agg_bookings["occ_pct"]=df_agg_bookings["successful_bookings"]/df_agg_bookings["capacity"]

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 4  0.947368
# 5  0.700000

# %%
df_agg_bookings = df_agg_bookings.assign(occ_pct=df_agg_bookings['occ_pct'] / 100)
df_agg_bookings.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 4    94.74

# %% [markdown]
# **INSIGHT GENERATION**

# %% [markdown]
# **1. What is an average occupancy rate in each of the room categories?**

# %%
df_agg_bookings.groupby("room_category")["occ_pct"].mean().round(2)
# Out:
# room_category
# RT1    5788.96
# RT2    5800.98
# RT3    5802.82
# RT4    5927.79
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df=pd.merge(df_agg_bookings,df_rooms,left_on="room_category",right_on="room_id")
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3    94.74     RT1   Standard

# %%
df.groupby("room_class")["occ_pct"].mean().round(2)
# Out:
# room_class
# Elite           58.01
# Premium         58.03
# Presidential    59.28
# Standard        57.89
# Name: occ_pct, dtype: float64

# %%
df.drop("room_id",axis=1,inplace=True)
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3    94.74   Standard

# %% [markdown]
# **Print average occupancy rate per city**

# %%
df_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# 17        18563   Atliq Palace  Business  Hyderabad
# 18        19558   Atliq Grands    Luxury  Bangalore
# 19        19559  Atliq Exotica    Luxury  Bangalore
# 20        19560     Atliq City  Business  Bangalore
# 21        19561      Atliq Blu    Luxury  Bangalore
# 22        19562      Atliq Bay    Luxury  Bangalore
# 23        19563   Atliq Palace  Business  Bangalore
# 24        17564  Atliq Seasons  Business     Mumbai

# %%
df=pd.merge(df,df_hotels,on="property_id")
df.head(4)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
#
#    occ_pct room_class property_name_x category_x     city_x property_name_y  \
# 0    83.33   Standard   Atliq Exotica     Luxury     Mumbai   Atliq Exotica
# 1    93.33   Standard       Atliq Bay     Luxury  Bangalore       Atliq Bay
# 2    76.67   Standard    Atliq Palace   Business  Bangalore    Atliq Palace
# 3    94.74   Standard    Atliq Grands     Luxury      Delhi    Atliq Grands
#
#   category_y     city_y
# 0     Luxury     Mumbai
# 1     Luxury  Bangalore
# 2   Business  Bangalore
# 3     Luxury      Delhi

# %%
df.groupby("city_y")["occ_pct"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='city_y'>

# %% [markdown]
# **When was the occupancy better?Weekday or Weekend?**

# %%
df_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
df=pd.merge(df,df_date,left_on="check_in_date",right_on="date")
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct room_class property_name_x category_x     city_x property_name_y  \
# 0    51.72    Premium    Atliq Palace   Business  Bangalore    Atliq Palace
# 1    63.33   Standard      Atliq City   Business  Hyderabad      Atliq City
# 2    60.00   Standard       Atliq Bay     Luxury  Bangalore       Atliq Bay
#
#   category_y     city_y       date  mmm yy week no  day_type
# 0   Business  Bangalore  10-May-22  May 22    W 20  weekeday
# 1   Business  Hyderabad  10-May-22  May 22    W 20  weekeday
# 2     Luxury  Bangalore  10-May-22  May 22    W 20  weekeday

# %%
df.groupby("day_type")["occ_pct"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='day_type'>

# %% [markdown]
# **In the month of June,what is the occupancy of different cities**

# %%
df["mmm yy"].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df_june_22=df[df["mmm yy"]=="Jun 22"]
df_june_22.head(3)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
#
#       occ_pct room_class property_name_x category_x     city_x  \
# 2200    66.67   Standard   Atliq Exotica     Luxury     Mumbai
# 2201    63.33   Standard       Atliq Bay     Luxury  Bangalore
# 2202    56.67   Standard    Atliq Palace   Business  Bangalore
#
#      property_name_y category_y     city_y       date  mmm yy week no  \
# 2200   Atliq Exotica     Luxury     Mumbai  10-Jun-22  Jun 22    W 24
# 2201       Atliq Bay     Luxury  Bangalore  10-Jun-22  Jun 22    W 24
# 2202    Atliq Palace   Business  Bangalore  10-Jun-22  Jun 22    W 24
#
#       day_type
# 2200  weekeday
# 2201  weekeday
# 2202  weekeday

# %%
df_june_22.groupby("city_x")["occ_pct"].mean().round(2).sort_values(ascending=False)
# Out:
# city_x
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.44
# Name: occ_pct, dtype: float64

# %%
df_august=pd.read_csv("datasets/new_data_august.csv")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
# 4        17558     10-May-22           RT1                   11      19.0
#
#    occ_pct room_class property_name_x category_x     city_x property_name_y  \
# 0    51.72    Premium    Atliq Palace   Business  Bangalore    Atliq Palace
# 1    63.33   Standard      Atliq City   Business  Hyderabad      Atliq City
# 2    60.00   Standard       Atliq Bay     Luxury  Bangalore       Atliq Bay
# 3    53.33   Standard    Atliq Palace   Business  Bangalore    Atliq Palace
# 4    57.89   Standard    Atliq Grands     Luxury     Mumbai    Atliq Grands
#
#   category_y     city_y       date  mmm yy week no  day_type
# 0   Business  Bangalore  10-May-22  May 22    W 20  weekeday
# 1   Business  Hyderabad  10-May-22  May 22    W 20  weekeday
# 2     Luxury  Bangalore  10-May-22  May 22    W 20  weekeday
# 3   Business  Bangalore  10-May-22  May 22    W 20  weekeday
# 4     Luxury     Mumbai  10-May-22  May 22    W 20  weekeday

# %%
latest_df=pd.concat([df,df_august],ignore_index=True,axis=0)
latest_df.tail(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6494        17558     31-Jul-22           RT4                    3       6.0
# 6495        19563     31-Jul-22           RT4                    3       6.0
# 6496        17561     31-Jul-22           RT4                    3       4.0
# 6497        16559     01-Aug-22           RT1                   30      30.0
# 6498        19562     01-Aug-22           RT1                   21      30.0
# 6499        19563     01-Aug-22           RT1                   23      30.0
# 6500        19558     01-Aug-22           RT1                   30      40.0
# 6501        19560     01-Aug-22           RT1                   20      26.0
# 6502        17561     01-Aug-22           RT1                   18      26.0
# 6503        17564     01-Aug-22           RT1                   10      16.0
#
#       occ_pct    room_class property_name_x category_x     city_x  ...  \
# 6494     50.0  Presidential    Atliq Grands     Luxury     Mumbai  ...
# 6495     50.0  Presidential    Atliq Palace   Business  Bangalore  ...
# 6496     75.0  Presidential       Atliq Blu     Luxury     Mumbai  ...
# 6497      NaN      Standard             NaN        NaN        NaN  ...
# 6498      NaN      Standard             NaN        NaN        NaN  ...
# 6499      NaN      Standard             NaN        NaN        NaN  ...
# 6500      NaN      Standard             NaN        NaN        NaN  ...
# 6501      NaN      Standard             NaN        NaN        NaN  ...
# 6502      NaN      Standard             NaN        NaN        NaN  ...
# 6503      NaN      Standard             NaN        NaN        NaN  ...
#
#      category_y     city_y       date  mmm yy week no  day_type  \
# 6494     Luxury     Mumbai  31-Jul-22  Jul 22    W 32   weekend
# 6495   Business  Bangalore  31-Jul-22  Jul 22    W 32   weekend
# 6496     Luxury     Mumbai  31-Jul-22  Jul 22    W 32   weekend
# 6497        NaN        NaN        NaN  Aug-22    W 32  weekeday
# 6498        NaN        NaN        NaN  Aug-22    W 32  weekeday
# 6499        NaN        NaN        NaN  Aug-22    W 32  weekeday
# 6500        NaN        NaN        NaN  Aug-22    W 32  weekeday
# 6501        NaN        NaN        NaN  Aug-22    W 32  weekeday
# 6502        NaN        NaN        NaN  Aug-22    W 32  weekeday
# 6503        NaN        NaN        NaN  Aug-22    W 32  weekeday
#
#       property_name  category       city    occ%
# 6494            NaN       NaN        NaN     NaN
# 6495            NaN       NaN        NaN     NaN
# 6496            NaN       NaN        NaN     NaN
# 6497  Atliq Exotica    Luxury     Mumbai  100.00
# 6498      Atliq Bay    Luxury  Bangalore   70.00
# 6499   Atliq Palace  Business  Bangalore   76.67
# 6500   Atliq Grands    Luxury  Bangalore   75.00
# 6501     Atliq City  Business  Bangalore   76.92
# 6502      Atliq Blu    Luxury     Mumbai   69.23
# 6503  Atliq Seasons  Business     Mumbai   62.50
#
# [10 rows x 21 columns]

# %% [markdown]
# **Print revenue realized per city**

# %%
df_bookings_all=pd.merge(df_bookings,df_hotels,on="property_id")
df_bookings_all.head(4)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
#
#    revenue_generated  revenue_realized property_name category   city
# 0              10010             10010  Atliq Grands   Luxury  Delhi
# 1               9100              3640  Atliq Grands   Luxury  Delhi
# 2            9100000              9100  Atliq Grands   Luxury  Delhi
# 3               9100              3640  Atliq Grands   Luxury  Delhi

# %%
df_bookings_all.groupby("city")["revenue_realized"].sum()
# Out:
# city
# Bangalore    420397050
# Delhi        294500318
# Hyderabad    325232870
# Mumbai       668640991
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **Print month by month revenue**

# %%
df_bookings_all["check_in_date"] = pd.to_datetime(df_bookings_all["check_in_date"], errors="coerce")
df_bookings_all
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22    2022-01-05
# 1        May012216558RT12        16558     30-04-22    2022-01-05
# 2        May012216558RT13        16558     28-04-22    2022-01-05
# 3        May012216558RT14        16558     28-04-22    2022-01-05
# 4        May012216558RT15        16558     27-04-22    2022-01-05
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564     29-07-22           NaT
# 134586   Jul312217564RT47        17564     30-07-22           NaT
# 134587   Jul312217564RT48        17564     30-07-22           NaT
# 134588   Jul312217564RT49        17564     29-07-22           NaT
# 134589  Jul312217564RT410        17564     31-07-22           NaT
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 1           2/5/2022        2.0           RT1           others            NaN
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# 4           2/5/2022        4.0           RT1    direct online            5.0
# ...              ...        ...           ...              ...            ...
# 134585      3/8/2022        1.0           RT4     makeyourtrip            2.0
# 134586      1/8/2022       -4.0           RT4          logtrip            2.0
# 134587      2/8/2022        1.0           RT4         tripster            NaN
# 134588      1/8/2022        2.0           RT4          logtrip            2.0
# 134589      1/8/2022        2.0           RT4     makeyourtrip            NaN
#
#        booking_status  revenue_generated  revenue_realized  property_name  \
# 0         Checked Out              10010             10010   Atliq Grands
# 1           Cancelled               9100              3640   Atliq Grands
# 2         Checked Out            9100000              9100   Atliq Grands
# 3           Cancelled               9100              3640   Atliq Grands
# 4         Checked Out              10920             10920   Atliq Grands
# ...               ...                ...               ...            ...
# 134585    Checked Out              32300             32300  Atliq Seasons
# 134586    Checked Out              38760             38760  Atliq Seasons
# 134587      Cancelled              32300             12920  Atliq Seasons
# 134588    Checked Out              32300             32300  Atliq Seasons
# 134589      Cancelled              32300             12920  Atliq Seasons
#
#         category    city
# 0         Luxury   Delhi
# 1         Luxury   Delhi
# 2         Luxury   Delhi
# 3         Luxury   Delhi
# 4         Luxury   Delhi
# ...          ...     ...
# 134585  Business  Mumbai
# 134586  Business  Mumbai
# 134587  Business  Mumbai
# 134588  Business  Mumbai
# 134589  Business  Mumbai
#
# [134590 rows x 15 columns]

# %%
df_date["date"]=pd.to_datetime(df_date["date"])
df_date.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_bookings_all=pd.merge(df_bookings_all,df_date,left_on="check_in_date",right_on="date")
df_bookings_all
# Out:
#              booking_id  property_id booking_date check_in_date checkout_date  \
# 0      May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1      May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2      May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
# 3      May052216558RT14        16558     3/5/2022    2022-05-05      6/5/2022
# 4      May052216558RT15        16558     30-04-22    2022-05-05     10/5/2022
# ...                 ...          ...          ...           ...           ...
# 13790  Jul072217564RT44        17564     4/7/2022    2022-07-07      8/7/2022
# 13791  Jul072217564RT45        17564     5/7/2022    2022-07-07      8/7/2022
# 13792  Jul072217564RT46        17564     5/7/2022    2022-07-07      9/7/2022
# 13793  Jul072217564RT47        17564     5/7/2022    2022-07-07      8/7/2022
# 13794  Jul072217564RT48        17564     5/7/2022    2022-07-07      8/7/2022
#
#        no_guests room_category booking_platform  ratings_given booking_status  \
# 0            3.0           RT1         tripster            5.0    Checked Out
# 1            2.0           RT1           others            NaN      Cancelled
# 2            3.0           RT1   direct offline            5.0    Checked Out
# 3            2.0           RT1         tripster            3.0    Checked Out
# 4            4.0           RT1           others            4.0    Checked Out
# ...          ...           ...              ...            ...            ...
# 13790        1.0           RT4     makeyourtrip            NaN    Checked Out
# 13791        1.0           RT4           others            2.0    Checked Out
# 13792        1.0           RT4     makeyourtrip            NaN    Checked Out
# 13793        2.0           RT4           others            NaN      Cancelled
# 13794        1.0           RT4          journey            1.0    Checked Out
#
#        ...  category    city     date_x mmm yy_x week no_x day_type_x  \
# 0      ...    Luxury   Delhi 2022-05-05   May 22      W 19   weekeday
# 1      ...    Luxury   Delhi 2022-05-05   May 22      W 19   weekeday
# 2      ...    Luxury   Delhi 2022-05-05   May 22      W 19   weekeday
# 3      ...    Luxury   Delhi 2022-05-05   May 22      W 19   weekeday
# 4      ...    Luxury   Delhi 2022-05-05   May 22      W 19   weekeday
# ...    ...       ...     ...        ...      ...       ...        ...
# 13790  ...  Business  Mumbai 2022-07-07   Jul 22      W 28   weekeday
# 13791  ...  Business  Mumbai 2022-07-07   Jul 22      W 28   weekeday
# 13792  ...  Business  Mumbai 2022-07-07   Jul 22      W 28   weekeday
# 13793  ...  Business  Mumbai 2022-07-07   Jul 22      W 28   weekeday
# 13794  ...  Business  Mumbai 2022-07-07   Jul 22      W 28   weekeday
#
#           date_y mmm yy_y week no_y day_type_y
# 0     2022-05-05   May 22      W 19   weekeday
# 1     2022-05-05   May 22      W 19   weekeday
# 2     2022-05-05   May 22      W 19   weekeday
# 3     2022-05-05   May 22      W 19   weekeday
# 4     2022-05-05   May 22      W 19   weekeday
# ...          ...      ...       ...        ...
# 13790 2022-07-07   Jul 22      W 28   weekeday
# 13791 2022-07-07   Jul 22      W 28   weekeday
# 13792 2022-07-07   Jul 22      W 28   weekeday
# 13793 2022-07-07   Jul 22      W 28   weekeday
# 13794 2022-07-07   Jul 22      W 28   weekeday
#
# [13795 rows x 23 columns]

# %%
df_bookings_all.groupby("mmm yy_x")["revenue_realized"].sum()
# Out:
# mmm yy_x
# Jul 22    60278496
# Jun 22    52903014
# May 22    60961428
# Name: revenue_realized, dtype: int64

# %%
df_bookings_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13795 entries, 0 to 13794
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   booking_id         13795 non-null  object
#  1   property_id        13795 non-null  int64
#  2   booking_date       13795 non-null  object
#  3   check_in_date      13795 non-null  datetime64[ns]
#  4   checkout_date      13795 non-null  object
#  5   no_guests          13795 non-null  float64
#  6   room_category      13795 non-null  object
#  7   booking_platform   13795 non-null  object
#  8   ratings_given      5673 non-null   float64
#  9   booking_status     13795 non-null  object
#  10  revenue_generated  13795 non-null  int64
#  11  revenue_realized   13795 non-null  int64
#  12  property_name      13795 non-null  object
#  13  category           13795 non-null  object
#  14  city               13795 non-null  object
#  15  date_x             13795 non-null  datetime64[ns]
#  16  mmm yy_x           13795 non-null  object
#  17  week no_x          13795 non-null  object
#  18  day_type_x         13795 non-null  object
#  19  date_y             13795 non-null  datetime64[ns]
#  20  mmm yy_y           13795 non-null  object
#  21  week no_y          13795 non-null  object
#  22  day_type_y         13795 non-null  object
# dtypes: datetime64[ns](3), float64(2), int64(3), object(15)
# memory usage: 2.4+ MB

# %%
df_bookings_all["mmm yy"] = df_bookings_all["check_in_date"].dt.strftime('%b %y')
df_bookings_all
# Out:
#              booking_id  property_id booking_date check_in_date checkout_date  \
# 0      May052216558RT11        16558     15-04-22    2022-05-05      7/5/2022
# 1      May052216558RT12        16558     30-04-22    2022-05-05      7/5/2022
# 2      May052216558RT13        16558     1/5/2022    2022-05-05      6/5/2022
# 3      May052216558RT14        16558     3/5/2022    2022-05-05      6/5/2022
# 4      May052216558RT15        16558     30-04-22    2022-05-05     10/5/2022
# ...                 ...          ...          ...           ...           ...
# 13790  Jul072217564RT44        17564     4/7/2022    2022-07-07      8/7/2022
# 13791  Jul072217564RT45        17564     5/7/2022    2022-07-07      8/7/2022
# 13792  Jul072217564RT46        17564     5/7/2022    2022-07-07      9/7/2022
# 13793  Jul072217564RT47        17564     5/7/2022    2022-07-07      8/7/2022
# 13794  Jul072217564RT48        17564     5/7/2022    2022-07-07      8/7/2022
#
#        no_guests room_category booking_platform  ratings_given booking_status  \
# 0            3.0           RT1         tripster            5.0    Checked Out
# 1            2.0           RT1           others            NaN      Cancelled
# 2            3.0           RT1   direct offline            5.0    Checked Out
# 3            2.0           RT1         tripster            3.0    Checked Out
# 4            4.0           RT1           others            4.0    Checked Out
# ...          ...           ...              ...            ...            ...
# 13790        1.0           RT4     makeyourtrip            NaN    Checked Out
# 13791        1.0           RT4           others            2.0    Checked Out
# 13792        1.0           RT4     makeyourtrip            NaN    Checked Out
# 13793        2.0           RT4           others            NaN      Cancelled
# 13794        1.0           RT4          journey            1.0    Checked Out
#
#        ...    city     date_x mmm yy_x week no_x day_type_x     date_y  \
# 0      ...   Delhi 2022-05-05   May 22      W 19   weekeday 2022-05-05
# 1      ...   Delhi 2022-05-05   May 22      W 19   weekeday 2022-05-05
# 2      ...   Delhi 2022-05-05   May 22      W 19   weekeday 2022-05-05
# 3      ...   Delhi 2022-05-05   May 22      W 19   weekeday 2022-05-05
# 4      ...   Delhi 2022-05-05   May 22      W 19   weekeday 2022-05-05
# ...    ...     ...        ...      ...       ...        ...        ...
# 13790  ...  Mumbai 2022-07-07   Jul 22      W 28   weekeday 2022-07-07
# 13791  ...  Mumbai 2022-07-07   Jul 22      W 28   weekeday 2022-07-07
# 13792  ...  Mumbai 2022-07-07   Jul 22      W 28   weekeday 2022-07-07
# 13793  ...  Mumbai 2022-07-07   Jul 22      W 28   weekeday 2022-07-07
# 13794  ...  Mumbai 2022-07-07   Jul 22      W 28   weekeday 2022-07-07
#
#       mmm yy_y week no_y day_type_y  mmm yy
# 0       May 22      W 19   weekeday  May 22
# 1       May 22      W 19   weekeday  May 22
# 2       May 22      W 19   weekeday  May 22
# 3       May 22      W 19   weekeday  May 22
# 4       May 22      W 19   weekeday  May 22
# ...        ...       ...        ...     ...
# 13790   Jul 22      W 28   weekeday  Jul 22
# 13791   Jul 22      W 28   weekeday  Jul 22
# 13792   Jul 22      W 28   weekeday  Jul 22
# 13793   Jul 22      W 28   weekeday  Jul 22
# 13794   Jul 22      W 28   weekeday  Jul 22
#
# [13795 rows x 24 columns]

# %%
df_bookings_all.groupby("property_name")["revenue_realized"].sum().round(2).sort_values()
# Out:
# property_name
# Atliq Seasons     6672245
# Atliq Grands     21644446
# Atliq Blu        26459751
# Atliq Bay        26936115
# Atliq City       29047727
# Atliq Palace     30945855
# Atliq Exotica    32436799
# Name: revenue_realized, dtype: int64

# %%
df_bookings_all.groupby("city")["ratings_given"].mean().round(2)
# Out:
# city
# Bangalore    3.41
# Delhi        3.79
# Hyderabad    3.65
# Mumbai       3.63
# Name: ratings_given, dtype: float64

# %%
df_bookings_all.groupby("booking_platform")["revenue_realized"].sum().plot(kind="pie")
# Out:
# <Axes: ylabel='revenue_realized'>
